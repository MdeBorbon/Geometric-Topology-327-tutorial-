# %%
K = Knots().from_table(6,1)

# %%
K.determinant()
# Out:
# 9

# %%
K.is_colorable(3)
# Out:
# True

# %%
K.plot(color=K.colorings(3)[0])
# Out:
# Graphics object consisting of 30 graphics primitives

# %% [markdown]
# The diagram is not alternating (but the one of the sheet is). Both diagrams represent the knot 6_1 from Rolfsen's table.
