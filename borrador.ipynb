# %%
K = Knots().an_element() ; K
# Out:
# Knot represented by 3 crossings

# %%
K.dt_code()
# Out:
# [4, 6, 2]

# %%
K.dowker_notation()
# Out:
# [(1, 4), (5, 2), (3, 6)]

# %%
K.plot()
# Out:
# Graphics object consisting of 14 graphics primitives

# %%
 b = K.braid()

# %%
K.determinant()
# Out:
# 3

# %%
K.signature()
# Out:
# 2

# %%
b.plot()
# Out:
# Graphics object consisting of 9 graphics primitives

# %%
K.writhe()
# Out:
# -3
