# %%
W = Knots()

# %%
K = W.from_dowker_code([2,4])

# %%
K.plot()
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
K.pd_code()
# Out:
# [[1, 3, 2, 2], [3, 1, 4, 4]]

# %%
K.jones_polynomial()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-5f38c022db52> in <module>
# ----> 1 K.jones_polynomial()
#
# /usr/lib/python3/dist-packages/sage/knots/link.py in jones_polynomial(self, variab, skein_normalization, algorithm)
#    2404                 return jones(SR(variab)**(ZZ(1)/ZZ(4))).expand()
#    2405         elif algorithm == 'jonesrep':
# -> 2406             return self.braid().jones_polynomial(variab, skein_normalization)
#    2407
#    2408         raise ValueError("bad value of algorithm")
#
# /usr/lib/python3/dist-packages/sage/knots/link.py in braid(self)
#     669                             newPD.append([newedge + 3, a, b, newedge])
#     670                             newPD.append([newedge + 2, newedge + 1, newedge + 3, newedge])
# --> 671                             self._braid = Link(newPD).braid()
# ...
